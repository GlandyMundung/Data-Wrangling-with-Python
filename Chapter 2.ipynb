# %% [markdown]
# # DQLAB DATA WRANGLING (CH2)

# %% [markdown]
# ## MISSING DATA

# %%
#pengecekan null data
import pandas as pd

csv_data = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/shopping_data_missingvalue.csv")

print(csv_data.isnull().values.any())
# Out:
# True

# %%
from IPython.display import Image
Image(filename='D:\programming\Python\DQLab\Data Wrangling\Solusi Missing Values.png')

# %% [markdown]
# ## Mengisi Null Value dengan Mean

# %%
import pandas as pd

csv_data = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/shopping_data_missingvalue.csv")

print(csv_data.mean())
print("Dataset yang masih terdapat nilai kosong ! :")
print(csv_data.head(10))

print("")

csv_data=csv_data.fillna(csv_data.mean())
print("Dataset yang sudah diproses Handling Missing Values dengan Mean :")
print(csv_data.head(10))
# Out:
# CustomerID                100.500000
# Age                        38.939698
# Annual Income (k$)         61.005051
# Spending Score (1-100)     50.489899
# dtype: float64
# Dataset yang masih terdapat nilai kosong ! :
#    CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                    39.0
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                 NaN                     6.0
# 3           4  Female  23.0                16.0                    77.0
# 4           5  Female  31.0                17.0                     NaN
# 5           6  Female  22.0                 NaN                    76.0
# 6           7  Female  35.0                18.0                     6.0
# 7           8  Female  23.0                18.0                    94.0
# 8           9    Male  64.0                19.0                     NaN
# 9          10  Female  30.0                19.0                    72.0
#
# Dataset yang sudah diproses Handling Missing Values dengan Mean :
#    CustomerID   Genre        Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.000000           15.000000               39.000000
# 1           2    Male  38.939698           15.000000               81.000000
# 2           3  Female  20.000000           61.005051                6.000000
# 3           4  Female  23.000000           16.000000               77.000000
# 4           5  Female  31.000000           17.000000               50.489899
# 5           6  Female  22.000000           61.005051               76.000000
# 6           7  Female  35.000000           18.000000                6.000000
# 7           8  Female  23.000000           18.000000               94.000000
# 8           9    Male  64.000000           19.000000               50.489899
# 9          10  Female  30.000000           19.000000               72.000000
# <ipython-input-4-f968e027df48>:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(csv_data.mean())
# <ipython-input-4-f968e027df48>:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv_data=csv_data.fillna(csv_data.mean())

# %% [markdown]
# ## Mengisi Null Value dengan Median

# %%
import pandas as pd

csv_data = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/shopping_data_missingvalue.csv")

print(csv_data.median())
print("Dataset yang masih terdapat nilai kosong ! :")
print(csv_data.head(10))

print("")

csv_data=csv_data.fillna(csv_data.median())
print("Dataset yang sudah diproses Handling Missing Values dengan Median :")
print(csv_data.head(10))
# Out:
# CustomerID                100.5
# Age                        36.0
# Annual Income (k$)         62.0
# Spending Score (1-100)     50.0
# dtype: float64
# Dataset yang masih terdapat nilai kosong ! :
#    CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                    39.0
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                 NaN                     6.0
# 3           4  Female  23.0                16.0                    77.0
# 4           5  Female  31.0                17.0                     NaN
# 5           6  Female  22.0                 NaN                    76.0
# 6           7  Female  35.0                18.0                     6.0
# 7           8  Female  23.0                18.0                    94.0
# 8           9    Male  64.0                19.0                     NaN
# 9          10  Female  30.0                19.0                    72.0
#
# Dataset yang sudah diproses Handling Missing Values dengan Median :
#    CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                    39.0
# 1           2    Male  36.0                15.0                    81.0
# 2           3  Female  20.0                62.0                     6.0
# 3           4  Female  23.0                16.0                    77.0
# 4           5  Female  31.0                17.0                    50.0
# 5           6  Female  22.0                62.0                    76.0
# 6           7  Female  35.0                18.0                     6.0
# 7           8  Female  23.0                18.0                    94.0
# 8           9    Male  64.0                19.0                    50.0
# 9          10  Female  30.0                19.0                    72.0
# <ipython-input-5-1b894f88b88e>:5: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(csv_data.median())
# <ipython-input-5-1b894f88b88e>:11: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   csv_data=csv_data.fillna(csv_data.median())

# %% [markdown]
# ## Normalisasi Data

# %%
from IPython.display import Image
Image(filename='D:\programming\Python\DQLab\Data Wrangling\Data Normalization.png')

# %%
from sklearn import preprocessing

array = csv_data.values

X = array[:,2:5] #memisahkan fitur dari dataset
Y = array[:,0:1] #memisahkan class dari dataset

dataset=pd.DataFrame({'Customer ID':array[:,0],'Gender':array[:,1], 'Age':array[:,2],'Income':array[:,3],'Spending Score':array[:,4]})
print("dataset sebelum dinormalisasi :")
print(dataset.head(10))

min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0,1)) #inisialisasi normalisasi MinMax
data = min_max_scaler.fit_transform(X) # transformasi MinMax untuk fitur
dataset = pd.DataFrame({'Age':data[:,0],'Income':data[:,1],'Spending Score':data[:,2],'Customer ID':array[:,0],'Gender':array[:,1]})

print("dataset setelah dinormalisasi :")
print(dataset.head(10))
# Out:
# dataset sebelum dinormalisasi :
#   Customer ID  Gender   Age Income Spending Score
# 0           1    Male  19.0   15.0           39.0
# 1           2    Male  36.0   15.0           81.0
# 2           3  Female  20.0   62.0            6.0
# 3           4  Female  23.0   16.0           77.0
# 4           5  Female  31.0   17.0           50.0
# 5           6  Female  22.0   62.0           76.0
# 6           7  Female  35.0   18.0            6.0
# 7           8  Female  23.0   18.0           94.0
# 8           9    Male  64.0   19.0           50.0
# 9          10  Female  30.0   19.0           72.0
# dataset setelah dinormalisasi :
#         Age    Income  Spending Score Customer ID  Gender
# 0  0.019231  0.000000        0.387755           1    Male
# 1  0.346154  0.000000        0.816327           2    Male
# 2  0.038462  0.385246        0.051020           3  Female
# 3  0.096154  0.008197        0.775510           4  Female
# 4  0.250000  0.016393        0.500000           5  Female
# 5  0.076923  0.385246        0.765306           6  Female
# 6  0.326923  0.024590        0.051020           7  Female
# 7  0.096154  0.024590        0.948980           8  Female
# 8  0.884615  0.032787        0.500000           9    Male
# 9  0.230769  0.032787        0.724490          10  Female
